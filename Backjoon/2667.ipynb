# %% [markdown]
# ### 문제
# - 1은 집이 있는 곳을, 0은 집이 없는 곳을 나타낸다. 철수는 이 지도를 가지고 연결된 집의 모임인 단지를 정의하고, 단지에 번호를 붙이려 한다. 여기서 연결되었다는 것은 어떤 집이 좌우, 혹은 아래위로 다른 집이 있는 경우를 말한다. 대각선상에 집이 있는 경우는 연결된 것이 아니다. 지도를 입력하여 단지수를 출력하고, 각 단지에 속하는 집의 수를 오름차순으로 정렬하여 출력하는 프로그램을 작성하시오.

# %% [markdown]
# ### 입력
# - 첫 번째 줄에는 지도의 크기 N(정사각형이므로 가로와 세로의 크기는 같으며 5≤N≤25)이 입력되고, 그 다음 N줄에는 각각 N개의 자료(0혹은 1)가 입력된다.

# %% [markdown]
# ### 출력
# - 첫 번째 줄에는 총 단지수를 출력하시오. 그리고 각 단지내 집의 수를 오름차순으로 정렬하여 한 줄에 하나씩 출력하시오.

# %%
def dfs(lst, i, j):
  global visit, c

  if visit[i][j] == True or lst[i][j] == '0':
    return

  c += 1
  visit[i][j] = True

  dx = [0, 0, -1, 1]
  dy = [1, -1, 0, 0]
  for idx in range(4):
    di = i + dx[idx]
    dj = j + dy[idx]
    if 0 <= di < N and 0 <= dj < N:
      dfs(lst, di, dj)

N = int(input())
lst = [list(input()) for _ in range(N)]
visit = [[False]*N for _ in range(N)]
count = 0
house = []

for i in range(N):
  for j in range(N):
    c = 0
    if visit[i][j] == False and lst[i][j] == '1':
      dfs(lst, i, j)
      house.append(c)
      count += 1

print(count)
house.sort()
for i in house:
  print(i)
# Out:
# 7
# 0110100
# 0110101
# 1110101
# 0000111
# 0100000
# 0111110
# 0111000
# 3
# 7
# 8
# 9
